# %%
import pandas as pd

df = pd.read_csv("HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.shape

# %%
df.info()

# %%
df['Attrition'].value_counts()

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.figure(figsize=(6,5))
sns.countplot(x='Attrition', data=df)
plt.title("Employee Attrition Distribution")
plt.xlabel("Attrition")
plt.ylabel("Count")
plt.show()

# %%
attrition_rate = (df['Attrition'].value_counts(normalize=True)['Yes']) * 100
print("Attrition Rate:", round(attrition_rate, 2), "%")
# Out:
# Attrition Rate: 16.12 %

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Department', hue='Attrition', data=df)
plt.title("Attrition by Department")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='JobRole', hue='Attrition', data=df)
plt.title("Attrition by Job Role")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.countplot(x='OverTime', hue='Attrition', data=df)
plt.title("Overtime vs Attrition")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.countplot(x='Gender', hue='Attrition', data=df)
plt.title("Gender-wise Attrition")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title("Employee Age Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['MonthlyIncome'], bins=30, kde=True)
plt.title("Monthly Income Distribution")
plt.show()

# %%
# !pip install streamlit plotly
# Out:
# Requirement already satisfied: streamlit in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (1.32.0)
# Requirement already satisfied: plotly in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (5.22.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (2.32.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\lubna shireen\downloads\python\anaconda navigator\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
